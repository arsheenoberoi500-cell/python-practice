# %%
import numpy as np

# %%
#mean is nothing but average

data=np.array([10,20,30,40])
print(np.mean(data))
# Out:
# 25.0

# %%
print(np.median(data)) #median is nothing but middle value
# Out:
# 25.0

# %%
print(np.absolute(-1))   #abs() = remove the negative sign / give the distance from zero.
# Out:
# 1
