# %%
import numpy as np

# %%
val=np.array([4,9,16])  #NumPy applies mathematical operations element-wise (to each element individually).
print(val)
# Out:
# [ 4  9 16]

# %%
val= val + 1
print(val)
# Out:
# [ 5 10 17]

# %%
val= val-1
print(val)
# Out:
# [ 4  9 16]

# %%
#wap to multiply 5 to all the elements

val= val*5
print(val)
# Out:
# [20 45 80]
